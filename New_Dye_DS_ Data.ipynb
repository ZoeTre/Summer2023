# %% [markdown]
# # 7/21

# %%
import csv 

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

# %%
# df_21 = pd.read_csv("721_aspiration.csv")

# df_21["width"] = (df_21["Three-phase point (r) [mm]"] - df_21["Three-phase point (l) [mm]"])/10

# df_21.head()

# split_loc_21 = []


# for index, value in enumerate(df_21["Three-phase point (l) [mm]"]):
#     if index < len(df_21) -1:
#          angle_jump = (df_21.iloc[index + 1][3] - df_21.iloc[index][3])
#          #print(index, angle_jump)
 
#          if abs(angle_jump) > 1:
#              split_loc_21.append(index)
 
# print(split_loc_21)

# %% [markdown]
# # bb 10^-6 concentration

# %%
# df_bb1_21_1 = df_21.iloc[:split_loc_21[0]-1, :]

# df_bb1_21_2 = df_21.iloc[split_loc_21[0]:split_loc_21[1]-1, :]

# df_bb1_21_3 = df_21.iloc[split_loc_21[1]:split_loc_21[2]-1, :]

# df_bb1_21_4 = df_21.iloc[split_loc_21[2]:split_loc_21[3]-1, :]

# df_bb1_21_5 = df_21.iloc[split_loc_21[3]:split_loc_21[4]-1, :]

# df_bb1_21_6 = df_21.iloc[split_loc_21[4]+1:split_loc_21[5]-1, :]

# %%
#all wait times

# %%
# #1

# y_width1_bb1_21 = df_bb1_21_1["width"]
# x_degrees1_bb1_21 = df_bb1_21_1["CA(m) [°]"]
# plt.plot(x_degrees1_bb1_21, y_width1_bb1_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("1 s, bb dye 10^-6")
# plt.show()

# #2

# y_width2_bb1_21 = df_bb1_21_2["width"]
# x_degrees2_bb1_21 = df_bb1_21_2["CA(m) [°]"]
# plt.plot(x_degrees2_bb1_21, y_width2_bb1_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("10 s, bb dye 10^-6")
# plt.show()

# #3

# y_width3_bb1_21 = df_bb1_21_3["width"]
# x_degrees3_bb1_21 = df_bb1_21_3["CA(m) [°]"]
# plt.plot(x_degrees3_bb1_21, y_width3_bb1_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("20 s, bb dye 10^-6")
# plt.show()

# #4

# y_width4_bb1_21 = df_bb1_21_4["width"]
# x_degrees4_bb1_21 = df_bb1_21_4["CA(m) [°]"]
# plt.plot(x_degrees4_bb1_21, y_width4_bb1_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("40 s, bb dye 10^-6")
# plt.show()

# #5

# y_width5_bb1_21 = df_bb1_21_5["width"]
# x_degrees5_bb1_21 = df_bb1_21_5["CA(m) [°]"]
# plt.plot(x_degrees5_bb1_21, y_width5_bb1_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("60 s, bb dye 10^-6")
# plt.show()

# #6

# y_width6_bb1_21 = df_bb1_21_6["width"]
# x_degrees6_bb1_21 = df_bb1_21_6["CA(m) [°]"]
# plt.plot(x_degrees6_bb1_21, y_width6_bb1_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("120 s, bb dye 10^-6")
# plt.show()

# %%
#all wait times side-by-side

# %%
# figure, axis = plt.subplots(2, 3, sharex = True, sharey= True, figsize = [20,10])

# #1

# axis[0,0].plot(x_degrees1_bb1_21, y_width1_bb1_21, 'o')
# axis[0,0].set_title("1 sec, 10^-6 bb dye")

# #2

# axis[0,1].plot(x_degrees2_bb1_21, y_width2_bb1_21, 'o')
# axis[0,1].set_title("10 sec, 10^-6 bb dye")

# #3

# axis[0,2].plot(x_degrees3_bb1_21, y_width3_bb1_21, 'o')
# axis[0,2].set_title("20 sec, 10^-6 bb dye")

# #4

# axis[1,0].plot(x_degrees4_bb1_21, y_width4_bb1_21, 'o')
# axis[1,0].set_title("40 sec, 10^-6 bb dye")

# #5

# axis[1,1].plot(x_degrees5_bb1_21, y_width5_bb1_21, 'o')
# axis[1,1].set_title("60 sec, 10^-6 bb dye")

# #6

# axis[1,2].plot(x_degrees5_bb1_21, y_width5_bb1_21, 'o')
# axis[1,2].set_title("120 sec, 10^-6 bb dye")


# plt.tight_layout()

# plt.show()

# %%
#wait times on top of each other

# %%
# plt.figure(figsize =[17,10])

# plt.plot(x_degrees1_bb1_21, y_width1_bb1_21, 'o', label="1 s wait time, bb dye")

# plt.plot(x_degrees2_bb1_21, y_width2_bb1_21, 'o', label="10 s wait time, bb dye")

# plt.plot(x_degrees3_bb1_21, y_width3_bb1_21, 'o', label="20 s wait time, bb dye")

# plt.plot(x_degrees4_bb1_21, y_width4_bb1_21, 'o', label="40 s wait time, bb dye")

# plt.plot(x_degrees5_bb1_21, y_width5_bb1_21, 'o', label="60 s wait time, bb dye")

# plt.plot(x_degrees6_bb1_21, y_width6_bb1_21, 'o', label="120 s wait time, bb dye")


# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("width vs angle for bb 10^-6 drop")
# plt.legend()

# #plt.xlim(20,80)

# plt.show()

# %%
# time6_bb1_21 = df_bb1_21_6["Elapsed time [s]"]

# %%
#angle vs time

# %%
# #plt.figure(figsize =[17,10])

# fig, ax = plt.subplots(figsize=[17,10])

# ax.plot(time6_bb1_21, x_degrees6_bb1_21, 'o')

# ax.set_xlabel('time (s)', fontsize=30)
# ax.set_ylabel('angle (degrees)', fontsize=30)

# ax.set_xlim(6,14)
# ax.set_xticks([6,8,10,12, 14])
# ax.set_ylim(0,75)
# ax.set_xticklabels([0,1,2,3,4])

# plt.xticks(fontsize = 25)
# plt.yticks(fontsize = 25)

# # plt.xlabel("time",fontsize=25)
# # plt.ylabel("angle",fontsize=25)
# #plt.title("angle vs time for bb 10^-6, 120s wait", fontsize=30)
# #plt.ylim(0,75)
# # plt.xlim(0, 14)
# # plt.yticks(fontsize=25)
# # plt.xticks(fontsize=25)


# plt.show()

# %%
#width vs time

# %%
# #plt.figure(figsize =[17,10])



# fig, ax = plt.subplots(figsize=[17,10])

# ax.plot(time6_bb1_21, y_width6_bb1_21, 'o')

# ax.set_xlabel('time (s)', fontsize=30)
# ax.set_ylabel('width (mm)', fontsize=30)

# plt.xticks(fontsize = 25)
# plt.yticks(fontsize = 25)

# ax.set_xlim(6,14)
# ax.set_xticks([6,8,10,12, 14])
# ax.set_ylim(0,5)


# ax.set_xticklabels([0,1,2,3,4])

# #ax.set_yticks([-1,0,1])

# plt.show()

# # plt.xlabel("time", fontsize=25)
# # plt.ylabel("width", fontsize=25)
# # plt.title("width vs time for bb 10^-6, 120s wait", fontsize=30)
# # plt.xticks(fontsize=25)
# #plt.yticks(fontsize=25)

# # plt.xlim(0,14)
# # plt.ylim(3.75, 5)


# # plt.show()

# %% [markdown]
# # bb 10^-5 diluted by half

# %%
# df_bb2_21_1 = df_21.iloc[split_loc_21[5]:split_loc_21[6]-1, :]

# df_bb2_21_2 = df_21.iloc[split_loc_21[6]:split_loc_21[7]-1, :]

# df_bb2_21_3 = df_21.iloc[split_loc_21[7]:split_loc_21[8]-1, :]

# df_bb2_21_4 = df_21.iloc[split_loc_21[8]:split_loc_21[9]-1, :]

# df_bb2_21_5 = df_21.iloc[split_loc_21[9]:split_loc_21[10]-1, :]

# df_bb2_21_6 = df_21.iloc[split_loc_21[10]:split_loc_21[11]-1, :]

# %%
#all wait times

# %%
# #1

# y_width1_bb2_21 = df_bb2_21_1["width"]
# x_degrees1_bb2_21 = df_bb2_21_1["CA(m) [°]"]
# plt.plot(x_degrees2_bb2_21, y_width2_bb2_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("1 s, bb dye 1/2")
# plt.show()

# #2

# y_width2_bb2_21 = df_bb2_21_2["width"]
# x_degrees2_bb2_21 = df_bb2_21_2["CA(m) [°]"]
# plt.plot(x_degrees2_bb2_21, y_width2_bb2_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("10 s, bb dye 1/2")
# plt.show()

# #3

# y_width3_bb2_21 = df_bb2_21_3["width"]
# x_degrees3_bb2_21 = df_bb2_21_3["CA(m) [°]"]
# plt.plot(x_degrees3_bb2_21, y_width3_bb2_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("20 s, bb dye 1/2")
# plt.show()

# #4

# y_width4_bb2_21 = df_bb2_21_4["width"]
# x_degrees4_bb2_21 = df_bb2_21_4["CA(m) [°]"]
# plt.plot(x_degrees4_bb2_21, y_width4_bb2_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("40 s, bb dye 1/2")
# plt.show()

# #5

# y_width5_bb2_21 = df_bb2_21_5["width"]
# x_degrees5_bb2_21 = df_bb2_21_5["CA(m) [°]"]
# plt.plot(x_degrees5_bb2_21, y_width5_bb2_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("60 s, bb dye 1/2")
# plt.show()

# #6

# y_width6_bb2_21 = df_bb2_21_6["width"]
# x_degrees6_bb2_21 = df_bb2_21_6["CA(m) [°]"]
# plt.plot(x_degrees6_bb2_21, y_width6_bb2_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("120 s, bb dye 1/2")
# plt.show()

# %%
#all wait times side-by-side

# %%
# figure, axis = plt.subplots(2, 3, sharex = True, sharey= True, figsize = [20,10])

# #1

# axis[0,0].plot(x_degrees1_bb2_21, y_width1_bb2_21, 'o')
# axis[0,0].set_title("1 sec, 1/2 bb dye")

# #2

# axis[0,1].plot(x_degrees2_bb2_21, y_width2_bb2_21, 'o')
# axis[0,1].set_title("10 sec, 1/2 bb dye")

# #3

# axis[0,2].plot(x_degrees3_bb2_21, y_width3_bb2_21, 'o')
# axis[0,2].set_title("20 sec, 1/2 bb dye")

# #4

# axis[1,0].plot(x_degrees4_bb2_21, y_width4_bb2_21, 'o')
# axis[1,0].set_title("40 sec, 1/2 bb dye")

# #5

# axis[1,1].plot(x_degrees5_bb2_21, y_width5_bb2_21, 'o')
# axis[1,1].set_title("60 sec, 1/2 bb dye")

# #6

# axis[1,2].plot(x_degrees5_bb2_21, y_width5_bb2_21, 'o')
# axis[1,2].set_title("120 sec, 1/2 bb dye")


# plt.tight_layout()

# plt.show()

# %%
#all wait times on top of each other

# %%
# plt.figure(figsize =[17,10])

# plt.plot(x_degrees1_bb2_21, y_width1_bb2_21, 'o', label="1 s wait time, bb dye")

# plt.plot(x_degrees2_bb2_21, y_width2_bb2_21, 'o', label="10 s wait time, bb dye")

# plt.plot(x_degrees3_bb2_21, y_width3_bb2_21, 'o', label="20 s wait time, bb dye")

# plt.plot(x_degrees4_bb2_21, y_width4_bb2_21, 'o', label="40 s wait time, bb dye")

# plt.plot(x_degrees5_bb2_21, y_width5_bb2_21, 'o', label="60 s wait time, bb dye")

# plt.plot(x_degrees6_bb2_21, y_width6_bb2_21, 'o', label="120 s wait time, bb dye")


# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("width vs angle for bb 1/2 drop")
# plt.legend()

# #plt.xlim(20,80)

# plt.show()

# %% [markdown]
# # bb 10^-5 concentration

# %%
# df_bb3_21_1 = df_21.iloc[split_loc_21[11]:split_loc_21[12]-1, :]

# df_bb3_21_2 = df_21.iloc[split_loc_21[12]:split_loc_21[13]-1, :]

# df_bb3_21_3 = df_21.iloc[split_loc_21[13]:split_loc_21[14]-1, :]

# df_bb3_21_4 = df_21.iloc[split_loc_21[14]:split_loc_21[15]-1, :]

# df_bb3_21_5 = df_21.iloc[split_loc_21[15]:split_loc_21[16]-1, :]

# df_bb3_21_6 = df_21.iloc[split_loc_21[16]+1:split_loc_21[17]+1, :]

# %%
#all wait times

# %%
# #1

# y_width1_bb3_21 = df_bb3_21_1["width"]
# x_degrees1_bb3_21 = df_bb3_21_1["CA(m) [°]"]
# plt.plot(x_degrees1_bb3_21, y_width1_bb3_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("1 s, bb dye 10^-5")
# plt.show()

# #2

# y_width2_bb3_21 = df_bb3_21_2["width"]
# x_degrees2_bb3_21 = df_bb3_21_2["CA(m) [°]"]
# plt.plot(x_degrees2_bb3_21, y_width2_bb3_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("10 s, bb dye 10^-5")
# plt.show()

# #3

# y_width3_bb3_21 = df_bb3_21_3["width"]
# x_degrees3_bb3_21 = df_bb3_21_3["CA(m) [°]"]
# plt.plot(x_degrees3_bb3_21, y_width3_bb3_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("20 s, bb dye 10^-5")
# plt.show()

# #4

# y_width4_bb3_21 = df_bb3_21_4["width"]
# x_degrees4_bb3_21 = df_bb3_21_4["CA(m) [°]"]
# plt.plot(x_degrees4_bb3_21, y_width4_bb3_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("40 s, bb dye 10^-5")
# plt.show()

# #5

# y_width5_bb3_21 = df_bb3_21_5["width"]
# x_degrees5_bb3_21 = df_bb3_21_5["CA(m) [°]"]
# plt.plot(x_degrees5_bb3_21, y_width5_bb3_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("60 s, bb dye 10^-5")
# plt.show()

# #6

# y_width6_bb3_21 = df_bb3_21_6["width"]
# x_degrees6_bb3_21 = df_bb3_21_6["CA(m) [°]"]
# plt.plot(x_degrees6_bb3_21, y_width6_bb3_21, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("120 s, bb dye 10^-5")
# plt.show()

# %%
#all wait times side-by-side

# %%
# figure, axis = plt.subplots(2, 3, sharex = True, sharey= True, figsize = [20,10])

# #1

# axis[0,0].plot(x_degrees1_bb3_21, y_width1_bb3_21, 'o')
# axis[0,0].set_title("1 sec, 10^-5 bb dye")

# #2

# axis[0,1].plot(x_degrees2_bb3_21, y_width2_bb3_21, 'o')
# axis[0,1].set_title("10 sec, 10^-5 bb dye")

# #3

# axis[0,2].plot(x_degrees3_bb3_21, y_width3_bb3_21, 'o')
# axis[0,2].set_title("20 sec, 10^-5 bb dye")

# #4

# axis[1,0].plot(x_degrees4_bb3_21, y_width4_bb3_21, 'o')
# axis[1,0].set_title("40 sec, 10^-5 bb dye")

# #5

# axis[1,1].plot(x_degrees5_bb3_21, y_width5_bb3_21, 'o')
# axis[1,1].set_title("60 sec, 10^-5 bb dye")

# #6

# axis[1,2].plot(x_degrees5_bb3_21, y_width5_bb3_21, 'o')
# axis[1,2].set_title("120 sec, 10^-5 bb dye")


# plt.tight_layout()

# plt.show()

# %%
#all wait times on top of each other

# %%
# plt.figure(figsize =[17,10])

# plt.plot(x_degrees1_bb3_21, y_width1_bb3_21, 'o', label="1 s wait time, bb dye")

# plt.plot(x_degrees2_bb3_21, y_width2_bb3_21, 'o', label="10 s wait time, bb dye")

# plt.plot(x_degrees3_bb3_21, y_width3_bb3_21, 'o', label="20 s wait time, bb dye")

# plt.plot(x_degrees4_bb3_21, y_width4_bb3_21, 'o', label="40 s wait time, bb dye")

# plt.plot(x_degrees5_bb3_21, y_width5_bb3_21, 'o', label="60 s wait time, bb dye")

# plt.plot(x_degrees6_bb3_21, y_width6_bb3_21, 'o', label="120 s wait time, bb dye")



# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("width vs angle for bb 1/2 drop")
# plt.legend()

# #plt.xlim(20,80)

# plt.show()

# %%
# time6_bb3_21 = df_bb3_21_6["Elapsed time [s]"]

# %%
# print(time6_bb3_21)

# %%
# x_degrees6_bb3_21

# with pd.option_context('display.max_rows', None,
#                        'display.max_columns', None,
#                        'display.precision', 3,
#                        ):

#     print(x_degrees6_bb3_21)

# %%
#angle vs time

# %%
# plt.figure(figsize =[17,10])

# plt.plot(time6_bb3_21, df_bb3_21_6["CA(m) [°]"], 'o')

# plt.xlabel("time")
# plt.ylabel("angle")
# plt.title("angle vs time for bb 10^-5, 120s wait")

# plt.show()

# %%
#width vs time

# %%
# plt.figure(figsize =[17,10])

# plt.plot(time6_bb3_21, y_width6_bb3_21, 'o')

# plt.xlabel("time")
# plt.ylabel("width")
# plt.title("width vs time for bb 10^-5, 120s wait")

# plt.ylim(3, 5)
# plt.show()

# %% [markdown]
# # 7/28

# %% [markdown]
# # bb dye 10^-8

# %%
# df_28 = pd.read_csv("728_aspiration.csv")

# df_28["width"] = (df_28["Three-phase point (r) [mm]"] - df_28["Three-phase point (l) [mm]"])/10

# df_28.head()

# split_loc_28 = []


# for index, value in enumerate(df_28["Three-phase point (l) [mm]"]):
#     if index < len(df_28) -1:
#          angle_jump = (df_28.iloc[index + 1][3] - df_28.iloc[index][3])
#          #print(index, angle_jump)
 
#          if abs(angle_jump) > 1:
#              split_loc_28.append(index)
 
# print(split_loc_28)
# Out:
# [83, 194, 282, 360, 495, 581, 651, 723, 799, 872, 952, 1022, 1102, 1182, 1258]

# %%
#wait times: 1s, 10s, 20s, 40s, 60s, 120s

# %%
df_bb1_28_1 = df_28.iloc[:split_loc_28[0]-1, :]

df_bb1_28_2 = df_28.iloc[split_loc_28[0]+1:split_loc_28[1]-1, :]

df_bb1_28_3 = df_28.iloc[split_loc_28[1]+1:split_loc_28[2]-1, :]

df_bb1_28_4 = df_28.iloc[split_loc_28[2]+1:split_loc_28[3]-1, :]

df_bb1_28_5 = df_28.iloc[split_loc_28[3]+1:split_loc_28[4]-1, :]

df_bb1_28_6 = df_28.iloc[split_loc_28[4]+1:split_loc_28[5]-1, :]

# %%
# #1

# y_width1_bb1_28 = df_bb1_28_1["width"]
# x_degrees1_bb1_28 = df_bb1_28_1["CA(m) [°]"]
# plt.plot(x_degrees1_bb1_28, y_width1_bb1_28, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("1 s, bb dye 10^-8")
# plt.show()

# #2

# y_width2_bb1_28 = df_bb1_28_2["width"]
# x_degrees2_bb1_28 = df_bb1_28_2["CA(m) [°]"]
# plt.plot(x_degrees2_bb1_28, y_width2_bb1_28, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("10 s, bb dye 10^-8")
# plt.show()

# #3

# y_width3_bb1_28 = df_bb1_28_3["width"]
# x_degrees3_bb1_28 = df_bb1_28_3["CA(m) [°]"]
# plt.plot(x_degrees3_bb1_28, y_width3_bb1_28, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("20 s, bb dye 10^-8")
# plt.show()

# #4

# y_width4_bb1_28 = df_bb1_28_4["width"]
# x_degrees4_bb1_28 = df_bb1_28_4["CA(m) [°]"]
# plt.plot(x_degrees4_bb1_28, y_width4_bb1_28, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("40 s, bb dye 10^-8")
# plt.show()

# #5

# y_width5_bb1_28 = df_bb1_28_5["width"]
# x_degrees5_bb1_28 = df_bb1_28_5["CA(m) [°]"]
# plt.plot(x_degrees5_bb1_28, y_width5_bb1_28, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("60 s, bb dye 10^-8")
# plt.show()

# #6

# y_width6_bb1_28 = df_bb1_28_6["width"]
# x_degrees6_bb1_28 = df_bb1_28_6["CA(m) [°]"]
# plt.plot(x_degrees6_bb1_28, y_width6_bb1_28, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("120 s, bb dye 10^-8")
# plt.show()

# %%
# import matplotlib.colors as mcolors
# from matplotlib import cm
# from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# plt.figure(figsize =[17,10])

# colorList = cm.get_cmap("viridis", 10) 


# plt.plot(x_degrees1_bb1_28, y_width1_bb1_28, 'o', label="1s", color=colorList.colors[0], markersize=7)

# plt.plot(x_degrees2_bb1_28, y_width2_bb1_28, 'x', label="10s", color=colorList.colors[2], markersize=10)

# plt.plot(x_degrees3_bb1_28, y_width3_bb1_28, 's', label="20s", color=colorList.colors[4], markersize=7)

# plt.plot(x_degrees4_bb1_28, y_width4_bb1_28, '*', label="40s", color=colorList.colors[6], markersize=10)

# plt.plot(x_degrees5_bb1_28, y_width5_bb1_28, '^', label="60s", color=colorList.colors[8], markersize=7)

# plt.plot(x_degrees6_bb1_28, y_width6_bb1_28, 'd', label="120s", color=colorList.colors[9], markersize=10)


# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("bb 10^-8")
# plt.legend(fontsize = 40)

# plt.xlim(0,80)


# plt.show()

# %% [markdown]
# # bb dye 10^-7

# %%
# df_bb2_28_1 = df_28.iloc[split_loc_28[5]+1:split_loc_28[6]-1, :]

# df_bb2_28_2 = df_28.iloc[split_loc_28[6]+1:split_loc_28[7]-1, :]

# df_bb2_28_3 = df_28.iloc[split_loc_28[7]+1:split_loc_28[8]-1, :]

# df_bb2_28_4 = df_28.iloc[split_loc_28[8]+1:split_loc_28[9]-1, :]

# df_bb2_28_5 = df_28.iloc[split_loc_28[9]+1:split_loc_28[10]-1, :]

# df_bb2_28_6 = df_28.iloc[split_loc_28[10]+1:split_loc_28[11]-1, :]

# %%
# #1

# y_width1_bb2_28 = df_bb2_28_1["width"]
# x_degrees1_bb2_28 = df_bb2_28_1["CA(m) [°]"]
# plt.plot(x_degrees1_bb2_28, y_width1_bb2_28, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("1 s, bb dye 10^-7")
# plt.show()

# #2

# y_width2_bb2_28 = df_bb2_28_2["width"]
# x_degrees2_bb2_28 = df_bb2_28_2["CA(m) [°]"]
# plt.plot(x_degrees2_bb2_28, y_width2_bb2_28, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("10 s, bb dye 10^-7")
# plt.show()

# #3

# y_width3_bb2_28 = df_bb2_28_3["width"]
# x_degrees3_bb2_28 = df_bb2_28_3["CA(m) [°]"]
# plt.plot(x_degrees3_bb2_28, y_width3_bb2_28, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("20 s, bb dye 10^-7")
# plt.show()

# #4

# y_width4_bb2_28 = df_bb2_28_4["width"]
# x_degrees4_bb2_28 = df_bb2_28_4["CA(m) [°]"]
# plt.plot(x_degrees4_bb2_28, y_width4_bb2_28, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("40 s, bb dye 10^-7")
# plt.show()

# #5

# y_width5_bb2_28 = df_bb2_28_5["width"]
# x_degrees5_bb2_28 = df_bb2_28_5["CA(m) [°]"]
# plt.plot(x_degrees5_bb2_28, y_width5_bb2_28, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("60 s, bb dye 10^-7")
# plt.show()

# #6

# y_width6_bb2_28 = df_bb2_28_6["width"]
# x_degrees6_bb2_28 = df_bb2_28_6["CA(m) [°]"]
# plt.plot(x_degrees6_bb2_28, y_width6_bb2_28, 'o')
# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("bb 10^-7")
# plt.show()

# %%
# import matplotlib.colors as mcolors
# from matplotlib import cm
# from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# plt.figure(figsize =[17,10])

# colorList = cm.get_cmap("viridis", 10) 

# plt.plot(x_degrees1_bb2_28, y_width1_bb2_28, 'o', label="1s", color=colorList.colors[0], markersize=7)

# plt.plot(x_degrees2_bb2_28, y_width2_bb2_28, 'x', label="10s", color=colorList.colors[2], markersize=10)

# plt.plot(x_degrees3_bb2_28, y_width3_bb2_28, 's', label="20s", color=colorList.colors[4], markersize=7)

# plt.plot(x_degrees4_bb2_28, y_width4_bb2_28, '*', label="40s", color=colorList.colors[6], markersize=10)

# plt.plot(x_degrees5_bb2_28, y_width5_bb2_28, '^', label="60s", color=colorList.colors[8], markersize=7)

# plt.plot(x_degrees6_bb2_28, y_width6_bb2_28, 'd', label="120s", color=colorList.colors[9], markersize=10)


# plt.xlabel("angle (degrees)")
# plt.ylabel("width (mm)")
# plt.title("bb 10^-7")
# plt.legend()

# plt.xlim(0,80)

# plt.show()

# %% [markdown]
# # 8/7 New Dye mixes

# %%
# 10^-5 , 5x10^-6 , 10^-6 , 10^-7

# %%
df_87 = pd.read_csv("87_aspiration.csv")

df_87["width"] = (df_87["Three-phase point (r) [mm]"] - df_87["Three-phase point (l) [mm]"])/10

df_87.head()

split_loc_87 = []


for index, value in enumerate(df_87["Three-phase point (l) [mm]"]):
    if index < len(df_87) -1:
         angle_jump = (df_87.iloc[index + 1][3] - df_87.iloc[index][3])
         #print(index, angle_jump)
 
         if abs(angle_jump) > 1:
             split_loc_87.append(index)
 
print(split_loc_87)
# Out:
# [78, 161, 241, 328, 409, 491, 560, 627, 707, 788, 856, 928, 1015, 1095, 1176, 1253, 1346]

# %% [markdown]
# # 10^-7

# %%
#wait times: 1s, 10s, 30s, 60s, 120s

# %%
df_bb1_87_1 = df_87.iloc[:split_loc_87[0]-1, :]

df_bb1_87_2 = df_87.iloc[split_loc_87[0]+1:split_loc_87[1]-1, :]

df_bb1_87_3 = df_87.iloc[split_loc_87[1]+1:split_loc_87[2]-1, :]

df_bb1_87_4 = df_87.iloc[split_loc_87[2]+1:split_loc_87[3]-1, :]

df_bb1_87_5 = df_87.iloc[split_loc_87[3]+1:split_loc_87[4]-1, :]

# %%
# 1

y_width1_bb1_87 = df_bb1_87_1["width"]
x_degrees1_bb1_87 = df_bb1_87_1["CA(m) [°]"]
plt.plot(x_degrees1_bb1_87, y_width1_bb1_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("1 s, bb dye 10^-7")
plt.show()

#2

y_width2_bb1_87 = df_bb1_87_2["width"]
x_degrees2_bb1_87 = df_bb1_87_2["CA(m) [°]"]
plt.plot(x_degrees2_bb1_87, y_width2_bb1_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("10 s, bb dye 10^-7")
plt.show()

#3

y_width3_bb1_87 = df_bb1_87_3["width"]
x_degrees3_bb1_87 = df_bb1_87_3["CA(m) [°]"]
plt.plot(x_degrees3_bb1_87, y_width3_bb1_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("30 s, bb dye 10^-7")
plt.show()

#4

y_width4_bb1_87 = df_bb1_87_4["width"]
x_degrees4_bb1_87 = df_bb1_87_4["CA(m) [°]"]
plt.plot(x_degrees4_bb1_87, y_width4_bb1_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("60 s, bb dye 10^-7")
plt.show()

#5

y_width5_bb1_87 = df_bb1_87_5["width"]
x_degrees5_bb1_87 = df_bb1_87_5["CA(m) [°]"]
plt.plot(x_degrees5_bb1_87, y_width5_bb1_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("120 s, bb dye 10^-7")
plt.show()

# %%
import matplotlib.colors as mcolors
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

plt.figure(figsize =[17,10])

colorList = cm.get_cmap("viridis", 10) 


plt.plot(x_degrees1_bb1_87, y_width1_bb1_87, 'o', label="1s", color=colorList.colors[0], markersize=7)

plt.plot(x_degrees2_bb1_87, y_width2_bb1_87, 'x', label="10s", color=colorList.colors[2], markersize=10)

plt.plot(x_degrees3_bb1_87, y_width3_bb1_87, 's', label="30s", color=colorList.colors[4], markersize=7)

plt.plot(x_degrees4_bb1_87, y_width4_bb1_87, '*', label="60s", color=colorList.colors[6], markersize=10)

plt.plot(x_degrees5_bb1_87, y_width5_bb1_87, '^', label="120s", color=colorList.colors[8], markersize=7)




plt.xlabel("angle (degrees)", fontsize=25)
plt.ylabel("width (mm)", fontsize=25)
plt.title("brilliant blue 10^-7", fontsize=30)
plt.legend(fontsize = 40)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

plt.xlim(0,80)
plt.ylim(0,5)

plt.show()

# %% [markdown]
# # 10^-6

# %%
df_bb2_87_1 = df_87.iloc[split_loc_87[4]+1:split_loc_87[5]-1, :]

df_bb2_87_2 = df_87.iloc[split_loc_87[5]+1:split_loc_87[6]-1, :]

df_bb2_87_3 = df_87.iloc[split_loc_87[6]+1:split_loc_87[7]-1, :]

df_bb2_87_4 = df_87.iloc[split_loc_87[7]+1:split_loc_87[8]-1, :]

# %%
#1

y_width1_bb2_87 = df_bb2_87_1["width"]
x_degrees1_bb2_87 = df_bb2_87_1["CA(m) [°]"]
plt.plot(x_degrees1_bb2_87, y_width1_bb2_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("1 s, bb dye 10^-6")
plt.show()

#2

y_width2_bb2_87 = df_bb2_87_2["width"]
x_degrees2_bb2_87 = df_bb2_87_2["CA(m) [°]"]
plt.plot(x_degrees2_bb2_87, y_width2_bb2_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("10 s, bb dye 10^-6")
plt.show()

#3

y_width3_bb2_87 = df_bb2_87_3["width"]
x_degrees3_bb2_87 = df_bb2_87_3["CA(m) [°]"]
plt.plot(x_degrees3_bb2_87, y_width3_bb2_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("30 s, bb dye 10^-6")
plt.show()

#4

y_width4_bb2_87 = df_bb2_87_4["width"]
x_degrees4_bb2_87 = df_bb2_87_4["CA(m) [°]"]
plt.plot(x_degrees4_bb2_87, y_width4_bb2_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("60 s, bb dye 10^-6")
plt.show()

# %%
plt.figure(figsize =[17,10])

colorList = cm.get_cmap("viridis", 10) 

plt.plot(x_degrees1_bb2_87, y_width1_bb2_87, 'o', label="1s", color=colorList.colors[0], markersize=7)

plt.plot(x_degrees2_bb2_87, y_width2_bb2_87, 'x', label="10s", color=colorList.colors[2], markersize=10)

plt.plot(x_degrees3_bb2_87, y_width3_bb2_87, 's', label="20s", color=colorList.colors[4], markersize=7)

plt.plot(x_degrees4_bb2_87, y_width4_bb2_87, '*', label="40s", color=colorList.colors[6], markersize=10)



plt.xlabel("angle (degrees)", fontsize=25)
plt.ylabel("width (mm)", fontsize=25)
plt.title("brilliant blue 10^-6", fontsize=30)
plt.legend(fontsize=40)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

plt.xlim(0,80)
plt.ylim(0,5)

plt.show()

# %% [markdown]
# # 5x10^-6

# %%
df_bb3_87_1 = df_87.iloc[split_loc_87[8]+1:split_loc_87[9]-1, :]

df_bb3_87_2 = df_87.iloc[split_loc_87[9]+1:split_loc_87[10]-1, :]

df_bb3_87_3 = df_87.iloc[split_loc_87[10]+1:split_loc_87[11]-1, :]

df_bb3_87_4 = df_87.iloc[split_loc_87[11]+1:split_loc_87[12]-1, :]

# %%
#1

y_width1_bb3_87 = df_bb3_87_1["width"]
x_degrees1_bb3_87 = df_bb3_87_1["CA(m) [°]"]
plt.plot(x_degrees1_bb3_87, y_width1_bb3_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("1 s, bb dye 5x10^-6")
plt.show()

#2

y_width2_bb3_87 = df_bb3_87_2["width"]
x_degrees2_bb3_87 = df_bb3_87_2["CA(m) [°]"]
plt.plot(x_degrees2_bb3_87, y_width2_bb3_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("10 s, bb dye 5x10^-6")
plt.show()

#3

y_width3_bb3_87 = df_bb3_87_3["width"]
x_degrees3_bb3_87 = df_bb3_87_3["CA(m) [°]"]
plt.plot(x_degrees3_bb3_87, y_width3_bb3_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("30 s, bb dye 5x10^-6")
plt.show()

#4

y_width4_bb3_87 = df_bb3_87_4["width"]
x_degrees4_bb3_87 = df_bb3_87_4["CA(m) [°]"]
plt.plot(x_degrees4_bb3_87, y_width4_bb3_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("60 s, bb dye 5x10^-6")
plt.show()

# %%
plt.figure(figsize =[17,10])

colorList = cm.get_cmap("viridis", 10) 

plt.plot(x_degrees1_bb3_87, y_width1_bb3_87, 'o', label="1s", color=colorList.colors[0], markersize=7)

plt.plot(x_degrees2_bb3_87, y_width2_bb3_87, 'x', label="10s", color=colorList.colors[2], markersize=10)

plt.plot(x_degrees3_bb3_87, y_width3_bb3_87, 's', label="20s", color=colorList.colors[4], markersize=7)

plt.plot(x_degrees4_bb3_87, y_width4_bb3_87, '*', label="40s", color=colorList.colors[6], markersize=10)



plt.xlabel("angle (degrees)", fontsize=25)
plt.ylabel("width (mm)", fontsize=25)
plt.title("brilliant blue 5x10^-6", fontsize=30)
plt.legend(fontsize=40)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

plt.xlim(0,80)
plt.ylim(0,5)

plt.show()

# %% [markdown]
# # 10^-5

# %%
df_bb4_87_1 = df_87.iloc[split_loc_87[12]+1:split_loc_87[13]-1, :]

df_bb4_87_2 = df_87.iloc[split_loc_87[13]+1:split_loc_87[14]-1, :]

df_bb4_87_3 = df_87.iloc[split_loc_87[14]+1:split_loc_87[15]-1, :]

df_bb4_87_4 = df_87.iloc[split_loc_87[15]+1:split_loc_87[16]-1, :]

# %%
#1

y_width1_bb4_87 = df_bb4_87_1["width"]
x_degrees1_bb4_87 = df_bb4_87_1["CA(m) [°]"]
plt.plot(x_degrees1_bb4_87, y_width1_bb4_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("1 s, bb dye 10^-5")
plt.show()

#2

y_width2_bb4_87 = df_bb4_87_2["width"]
x_degrees2_bb4_87 = df_bb4_87_2["CA(m) [°]"]
plt.plot(x_degrees2_bb4_87, y_width2_bb4_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("10 s, bb dye 10^-5")
plt.show()

#3

y_width3_bb4_87 = df_bb4_87_3["width"]
x_degrees3_bb4_87 = df_bb4_87_3["CA(m) [°]"]
plt.plot(x_degrees3_bb4_87, y_width3_bb4_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("30 s, bb dye 10^-5")
plt.show()

#4

y_width4_bb4_87 = df_bb4_87_4["width"]
x_degrees4_bb4_87 = df_bb4_87_4["CA(m) [°]"]
plt.plot(x_degrees4_bb4_87, y_width4_bb4_87, 'o')
plt.xlabel("angle (degrees)")
plt.ylabel("width (mm)")
plt.title("60 s, bb dye 10^-5")
plt.show()

# %%
plt.figure(figsize =[17,10])

colorList = cm.get_cmap("viridis", 10) 

plt.plot(x_degrees1_bb4_87, y_width1_bb4_87, 'o', label="1s", color=colorList.colors[0], markersize=7)

plt.plot(x_degrees2_bb4_87, y_width2_bb4_87, 'x', label="10s", color=colorList.colors[2], markersize=10)

plt.plot(x_degrees3_bb4_87, y_width3_bb4_87, 's', label="20s", color=colorList.colors[4], markersize=7)

plt.plot(x_degrees4_bb4_87, y_width4_bb4_87, '*', label="40s", color=colorList.colors[6], markersize=10)



plt.xlabel("angle (degrees)", fontsize=25)
plt.ylabel("width (mm)", fontsize=25)
plt.title("brilliant blue 10^-5", fontsize=30)
plt.legend(fontsize=40)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

plt.xlim(0,80)
plt.ylim(0,5)

plt.show()
